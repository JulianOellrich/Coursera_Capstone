# %% [markdown]
# <h1>The Battle of Neighborhoods</h1>

# %% [markdown]
# This Project is part of the IBM Data Science Professional Certificate Caoptone.

# %% [markdown]
# <b>Author</b>: Julian Oellrich

# %% [markdown]
# <h2>Table of content</h2>
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
# <ol>
#     <li><a>Introduction and Background</a></li>
#     <li><a>Setup and Libraries</a></li>
# </ol>

# %% [markdown]
# <h2 id="introduction">1. Introduction and Background</h2>

# %% [markdown]
# <p>There are many people who are working in various cities (say New York and Toronto) across the world. Let's say you live on the West side of the City of Toronto in Canada. You love your neighborhood mainly because of all the great amenities and other types of venues that exist in the neighborhood. Such as gourmet fast food joints, pharmacies, parks, grad schools, and so on. Now say you receive a job offer from a great company on the other side of the city with great career prospects. However, given the far distance from your current place, you unfortunately must move if you decide to accept the offer. Wouldn't it be great if you're able to determine neighborhoods on the other side of the city? There are exactly the same as your current neighborhood, and if not, perhaps similar neighborhoods that are at least closer to your new job.
# </p>
#
# <p>
# The goal of this capstone project ist to compare different neighborhoods in terms of a service. Search for potential explanation of why a neighborhood is popular. The cause of complaints in another neighborhood, or anything else related to neighborhoods. Hence the name of the capstone project will be the battle of the neighborhoods.</p>
#
# <p>
# In order to do this, given a city like the City of Toronto, we will segment it into different neighborhoods using the geographical coordinates of the center of each neighborhood. And then, using a combination of location data and machine learning, togroup the neighborhoods into clusters.
# </p>

# %% [markdown]
# <h2 id="libraries">2. Setup and Libraries</h2>

# %% [markdown]
# Import Libraries

# %%
# Comuptation Libraries
import pandas as pd
import numpy as np

# API Communication
import json, requests

# Maps

# ML Algorithms
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# Print Hello Statement

# %%
print('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!

# %% [markdown]
# <h2 id="Data">3. Data and Function definition</h2>

# %% [markdown]
# <h3 id="Data">3.2 Venue Search via Foursquare API</h3>

# %%
client_id    = 'LUYAHPN5TJHESOZ0M0IR4DWVVH3BXMXTECOVF4L2PNCXS2YV' # LUYAHPN5TJHESOZ0M0IR4DWVVH3BXMXTECOVF4L2PNCXS2YV
client_secret = 'JI3SI0ENMW45AYTRQUQQKHALUNFL34NMHW0S0I3DF10QEFCW' # JI3SI0ENMW45AYTRQUQQKHALUNFL34NMHW0S0I3DF10QEFCW
version      = '20180602'
limit        = 100

# %%
# search coordinates
lat = 40.73
lng = -74.01

# %%
# define venue search query
search_query = 'coffee'

# %%
url_search = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&v={}&ll={},{}&query={}'\
                .format(client_id, client_secret, version, lat, lng, search_query)

results = requests.get(url_search).json()

# %%
results
# Out:
# {'meta': {'code': 200, 'requestId': '5f96d5e96e2aa02db460f313'},
#  'response': {'venues': [{'id': '546cb126498eabb0f206d61f',
#     'name': 'Partners Coffee Roasters',
#     'location': {'address': '44 Charles St',
#      'crossStreet': 'at 7th Ave S',
#      'lat': 40.73491348804492,
#      'lng': -74.00205073261284,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.73491348804492,
#        'lng': -74.00205073261284},
#       {'label': 'entrance', 'lat': 40.734954, 'lng': -74.002239}],
#      'distance': 865,
#      'postalCode': '10014',
#      'cc': 'US',
#      'neighborhood': 'West Village',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['44 Charles St (at 7th Ave S)',
#       'New York, NY 10014',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603720681',
#     'hasPerk': False},
#    {'id': '55e9f118498eda28f897f9e3',
#     'name': 'Kobrick Coffee Co.',
#     'location': {'address': '24 9th Ave',
#      'crossStreet': 'btwn W 13th & 14th St',
#      'lat': 40.74033655451874,
#      'lng': -74.00569308386368,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.74033655451874,
#        'lng': -74.00569308386368},
#       {'label': 'entrance', 'lat': 40.740329, 'lng': -74.005607}],
#      'distance': 1206,
#      'postalCode': '10014',
#      'cc': 'US',
#      'neighborhood': 'Meatpacking District',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['24 9th Ave (btwn W 13th & 14th St)',
#       'New York, NY 10014',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '2033642',
#      'url': 'https://www.seamless.com/menu/kobrick-coffee-24-9th-ave-new-york/2033642?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2033642',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '141608237'},
#     'referralId': 'v-1603720681',
#     'hasPerk': False},
#    {'id': '512f8233e4b04458d4385195',
#     'name': 'Stumptown Coffee Roasters',
#     'location': {'address': '30 W 8th St',
#      'crossStreet': 'at MacDougal St',
#      'lat': 40.732797,
#      'lng': -73.997971,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.732797,
#        'lng': -73.997971}],
#      'distance': 1061,
#      'postalCode': '10011',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['30 W 8th St (at MacDougal St)',
#       'New York, NY 10011',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603720681',
#     'hasPerk': False},
#    {'id': '4aabd45bf964a5204d5a20e3',
#     'name': "McNulty's Tea & Coffee Co",
#     'location': {'address': '109 Christopher St',
#      'crossStreet': 'btwn Bleecker & W Hudson St.',
#      'lat': 40.733294099833444,
#      'lng': -74.00520280831209,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.733294099833444,
#        'lng': -74.00520280831209}],
#      'distance': 546,
#      'postalCode': '10014',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['109 Christopher St (btwn Bleecker & W Hudson St.)',
#       'New York, NY 10014',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1f5941735',
#       'name': 'Gourmet Shop',
#       'pluralName': 'Gourmet Shops',
#       'shortName': 'Gourmet',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_gourmet_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '593517048'},
#     'referralId': 'v-1603720681',
#     'hasPerk': False},
#    {'id': '4876216df964a52011511fe3',
#     'name': "Jack's Stir Brew Coffee",
#     'location': {'address': '138 W 10th St',
#      'crossStreet': 'btwn Greenwich Ave & Waverly Pl',
#      'lat': 40.73451,
#      'lng': -74.00062,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.73451,
#        'lng': -74.00062}],
#      'distance': 937,
#      'postalCode': '10014',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['138 W 10th St (btwn Greenwich Ave & Waverly Pl)',
#       'New York, NY 10014',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '161474147'},
#     'referralId': 'v-1603720681',
#     'hasPerk': False},
#    {'id': '4cd167456200b1f7d09fd928',
#     'name': 'Coffee Cart',
#     'location': {'address': '375 Hudson St',
#      'crossStreet': 'at Houston',
#      'lat': 40.72871101311086,
#      'lng': -74.00715251827633,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.72871101311086,
#        'lng': -74.00715251827633}],
#      'distance': 279,
#      'postalCode': '10014',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['375 Hudson St (at Houston)',
#       'New York, NY 10014',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603720681',
#     'hasPerk': False},
#    {'id': '4a534cc4f964a5202cb21fe3',
#     'name': 'Third Rail Coffee',
#     'location': {'address': '240 Sullivan St',
#      'crossStreet': 'btwn Bleecker & W 3rd St',
#      'lat': 40.729931452115565,
#      'lng': -73.99951321584003,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.729931452115565,
#        'lng': -73.99951321584003}],
#      'distance': 884,
#      'postalCode': '10012',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['240 Sullivan St (btwn Bleecker & W 3rd St)',
#       'New York, NY 10012',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '86408938'},
#     'referralId': 'v-1603720681',
#     'hasPerk': False},
#    {'id': '56054685498e21a5e4c9d5b2',
#     'name': 'Coffee Project New York',
#     'location': {'address': '239 E 5th St',
#      'crossStreet': 'btwn 2nd Ave & Bowery',
#      'lat': 40.727153,
#      'lng': -73.989527,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.727153,
#        'lng': -73.989527},
#       {'label': 'entrance', 'lat': 40.726978, 'lng': -73.989232}],
#      'distance': 1755,
#      'postalCode': '10003',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['239 E 5th St (btwn 2nd Ave & Bowery)',
#       'New York, NY 10003',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '146524785'},
#     'referralId': 'v-1603720681',
#     'hasPerk': False},
#    {'id': '519a94e3498e722d3d9ae1bf',
#     'name': 'Intelligentsia Coffee',
#     'location': {'address': '180 10th Ave',
#      'crossStreet': 'btwn W 20th & W 21st St',
#      'lat': 40.745925923501794,
#      'lng': -74.00537634340776,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.745925923501794,
#        'lng': -74.00537634340776}],
#      'distance': 1815,
#      'postalCode': '10011',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['180 10th Ave (btwn W 20th & W 21st St)',
#       'New York, NY 10011',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '147036863'},
#     'referralId': 'v-1603720681',
#     'hasPerk': False},
#    {'id': '5b8e66ac234724002c927c4b',
#     'name': 'Brooklyn Bagel & Coffee Company',
#     'location': {'address': '63 E 8th St',
#      'crossStreet': 'Mercer Street',
#      'lat': 40.730912575619136,
#      'lng': -73.9932591437105,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.730912575619136,
#        'lng': -73.9932591437105}],
#      'distance': 1415,
#      'postalCode': '10003',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['63 E 8th St (Mercer Street)',
#       'New York, NY 10003',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d179941735',
#       'name': 'Bagel Shop',
#       'pluralName': 'Bagel Shops',
#       'shortName': 'Bagels',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bagels_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603720681',
#     'hasPerk': False},
#    {'id': '4ecc046b0e61aaf0384f19c4',
#     'name': 'Think Coffee',
#     'location': {'address': '73 8th Ave',
#      'crossStreet': 'btwn W 13th & W 14th St',
#      'lat': 40.739479423087914,
#      'lng': -74.00270033729069,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.739479423087914,
#        'lng': -74.00270033729069},
#       {'label': 'entrance', 'lat': 40.739483, 'lng': -74.002924}],
#      'distance': 1221,
#      'postalCode': '10014',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['73 8th Ave (btwn W 13th & W 14th St)',
#       'New York, NY 10014',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603720681',
#     'hasPerk': False},
#    {'id': '4eb92d8af790d87d04498393',
#     'name': 'Coffee Wagon',
#     'location': {'address': 'Hudson and King',
#      'lat': 40.72823110830968,
#      'lng': -74.00578312188485,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.72823110830968,
#        'lng': -74.00578312188485}],
#      'distance': 406,
#      'postalCode': '10014',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Hudson and King',
#       'New York, NY 10014',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603720681',
#     'hasPerk': False},
#    {'id': '49c406a8f964a5208d561fe3',
#     'name': 'Brooklyn Bagel & Coffee Co.',
#     'location': {'address': '286 8th Ave',
#      'crossStreet': 'btwn W 24th & W 25th St',
#      'lat': 40.746236606826656,
#      'lng': -73.99793054220713,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.746236606826656,
#        'lng': -73.99793054220713},
#       {'label': 'entrance', 'lat': 40.746175, 'lng': -73.997639}],
#      'distance': 2074,
#      'postalCode': '10001',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['286 8th Ave (btwn W 24th & W 25th St)',
#       'New York, NY 10001',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d179941735',
#       'name': 'Bagel Shop',
#       'pluralName': 'Bagel Shops',
#       'shortName': 'Bagels',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bagels_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603720681',
#     'hasPerk': False},
#    {'id': '4f3a9e05bb3d2fbe725ca57a',
#     'name': 'Blue Bottle Coffee',
#     'location': {'address': '450 W 15th St',
#      'crossStreet': 'btwn 9th & 10th Ave',
#      'lat': 40.74247264215167,
#      'lng': -74.00698238537771,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.74247264215167,
#        'lng': -74.00698238537771},
#       {'label': 'entrance', 'lat': 40.742455, 'lng': -74.00705}],
#      'distance': 1411,
#      'postalCode': '10011',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['450 W 15th St (btwn 9th & 10th Ave)',
#       'New York, NY 10011',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603720681',
#     'hasPerk': False},
#    {'id': '491ada01f964a52072521fe3',
#     'name': 'Think Coffee',
#     'location': {'address': '1 Bleecker St',
#      'crossStreet': 'at Bowery',
#      'lat': 40.72526643084157,
#      'lng': -73.99234118219594,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.72526643084157,
#        'lng': -73.99234118219594}],
#      'distance': 1580,
#      'postalCode': '10012',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1 Bleecker St (at Bowery)',
#       'New York, NY 10012',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603720681',
#     'hasPerk': False},
#    {'id': '5cc82d711acf11002c0998f5',
#     'name': 'St Kilda Coffee',
#     'location': {'address': '213 8th Ave',
#      'crossStreet': 'btwn W 20th & 21st St',
#      'lat': 40.743854,
#      'lng': -73.99977,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.743854,
#        'lng': -73.99977}],
#      'distance': 1767,
#      'postalCode': '10011',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['213 8th Ave (btwn W 20th & 21st St)',
#       'New York, NY 10011',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603720681',
#     'hasPerk': False},
#    {'id': '5b89aecc8c812a002ca7f2af',
#     'name': 'Coffee Project New York',
#     'location': {'address': '78 Rockwell Pl',
#      'crossStreet': 'Fulton St',
#      'lat': 40.687751,
#      'lng': -73.979387,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.687751,
#        'lng': -73.979387}],
#      'distance': 5365,
#      'postalCode': '11217',
#      'cc': 'US',
#      'city': 'Brooklyn',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['78 Rockwell Pl (Fulton St)',
#       'Brooklyn, NY 11217',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603720681',
#     'hasPerk': False},
#    {'id': '3fd66200f964a52008e91ee3',
#     'name': 'Irving Farm Coffee Roasters',
#     'location': {'address': '71 Irving Pl',
#      'crossStreet': 'btwn E 18th & E 19th St',
#      'lat': 40.73671618830131,
#      'lng': -73.98681688095093,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.73671618830131,
#        'lng': -73.98681688095093},
#       {'label': 'entrance', 'lat': 40.736778, 'lng': -73.986886}],
#      'distance': 2093,
#      'postalCode': '10003',
#      'cc': 'US',
#      'neighborhood': 'Gramercy Park',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['71 Irving Pl (btwn E 18th & E 19th St)',
#       'New York, NY 10003',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603720681',
#     'hasPerk': False},
#    {'id': '5dba113267232c000803cb37',
#     'name': 'For Five Coffee Roasters',
#     'location': {'lat': 40.71224,
#      'lng': -74.014915,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71224,
#        'lng': -74.014915}],
#      'distance': 2020,
#      'postalCode': '10280',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY 10280', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '2368674',
#      'url': 'https://www.grubhub.com/restaurant/for-five-coffee-roasters----brookfield-place-225-liberty-st-new-york/2368674?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2368674',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1603720681',
#     'hasPerk': False},
#    {'id': '5204ffcf498e6b6c11d8adb1',
#     'name': 'Le Café Coffee',
#     'location': {'address': '7 E 14th St',
#      'crossStreet': 'btwn 5th Ave & University Pl',
#      'lat': 40.735700890675574,
#      'lng': -73.9928074098831,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.735700890675574,
#        'lng': -73.9928074098831}],
#      'distance': 1583,
#      'postalCode': '10003',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['7 E 14th St (btwn 5th Ave & University Pl)',
#       'New York, NY 10003',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '378265',
#      'url': 'https://www.seamless.com/menu/le-cafe-coffee-7-e-14th-st-new-york/378265?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=378265',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '76871178'},
#     'referralId': 'v-1603720681',
#     'hasPerk': False},
#    {'id': '583af456ce593d41644bd7a6',
#     'name': 'Kaigo Coffee Room',
#     'location': {'address': '120 Lafayette St Frnt C',
#      'lat': 40.71863256946489,
#      'lng': -74.00036738038041,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71863256946489,
#        'lng': -74.00036738038041}],
#      'distance': 1503,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['120 Lafayette St Frnt C',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603720681',
#     'hasPerk': False},
#    {'id': '49f37b88f964a520a26a1fe3',
#     'name': 'Empire Coffee & Tea',
#     'location': {'address': '338 Bloomfield St',
#      'crossStreet': 'at 4th St',
#      'lat': 40.74137492076492,
#      'lng': -74.0305153338276,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.74137492076492,
#        'lng': -74.0305153338276}],
#      'distance': 2144,
#      'postalCode': '07030',
#      'cc': 'US',
#      'city': 'Hoboken',
#      'state': 'NJ',
#      'country': 'United States',
#      'formattedAddress': ['338 Bloomfield St (at 4th St)',
#       'Hoboken, NJ 07030',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1884200',
#      'url': 'https://www.grubhub.com/restaurant/empire-coffee--tea-co-338-bloomfield-st-hoboken/1884200?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1884200',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'venuePage': {'id': '119534416'},
#     'referralId': 'v-1603720681',
#     'hasPerk': False},
#    {'id': '5df8e79880d839000816f937',
#     'name': 'Joe Coffee Company',
#     'location': {'address': '29 Union Sq W',
#      'lat': 40.736515145619016,
#      'lng': -73.99107006134227,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.736515145619016,
#        'lng': -73.99107006134227}],
#      'distance': 1753,
#      'postalCode': '10003',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['29 Union Sq W',
#       'New York, NY 10003',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603720681',
#     'hasPerk': False},
#    {'id': '5783fac6cd10361b6f2ca3fc',
#     'name': "Peet's Coffee",
#     'location': {'address': '853 Broadway,',
#      'lat': 40.734693,
#      'lng': -73.990975,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.734693,
#        'lng': -73.990975}],
#      'distance': 1687,
#      'postalCode': '10003',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['853 Broadway,',
#       'New York, NY 10003',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603720681',
#     'hasPerk': False},
#    {'id': '44dc96e4f964a520b0361fe3',
#     'name': 'Think Coffee',
#     'location': {'address': '248 Mercer St',
#      'crossStreet': 'btwn W 3rd & W 4th St',
#      'lat': 40.72830485635694,
#      'lng': -73.99551044983527,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.72830485635694,
#        'lng': -73.99551044983527}],
#      'distance': 1236,
#      'postalCode': '10012',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['248 Mercer St (btwn W 3rd & W 4th St)',
#       'New York, NY 10012',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603720681',
#     'hasPerk': False},
#    {'id': '580039c2d67c45aa557e1e46',
#     'name': 'Gregorys Coffee',
#     'location': {'address': '649 Broadway',
#      'crossStreet': 'at Bleecker St',
#      'lat': 40.7268895,
#      'lng': -73.995828,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7268895,
#        'lng': -73.995828}],
#      'distance': 1244,
#      'postalCode': '10012',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['649 Broadway (at Bleecker St)',
#       'New York, NY 10012',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1089564',
#      'url': 'https://www.seamless.com/menu/gregorys-coffee-649-broadway-new-york/1089564?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1089564',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '433964722'},
#     'referralId': 'v-1603720681',
#     'hasPerk': False},
#    {'id': '49c192c5f964a520b6551fe3',
#     'name': 'Joe Coffee Company',
#     'location': {'address': '405 W 23rd St',
#      'crossStreet': 'at 9th Ave.',
#      'lat': 40.74700652916005,
#      'lng': -74.00187650246409,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.74700652916005,
#        'lng': -74.00187650246409},
#       {'label': 'entrance', 'lat': 40.74679, 'lng': -74.001657}],
#      'distance': 2013,
#      'postalCode': '10011',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['405 W 23rd St (at 9th Ave.)',
#       'New York, NY 10011',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603720681',
#     'hasPerk': False},
#    {'id': '56227f05498e1de5733c0eaa',
#     'name': 'Le Cafe Coffee',
#     'location': {'address': '145 4th Ave',
#      'crossStreet': 'Between 13th And 14th St',
#      'lat': 40.733816291051085,
#      'lng': -73.98988962340907,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.733816291051085,
#        'lng': -73.98988962340907}],
#      'distance': 1748,
#      'postalCode': '10003',
#      'cc': 'US',
#      'neighborhood': 'Union Square, New York, NY',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['145 4th Ave (Between 13th And 14th St)',
#       'New York, NY 10003',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '767856',
#      'url': 'https://www.seamless.com/menu/le-cafe-coffee-145-4th-avenue-new-york/767856?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=767856',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1603720681',
#     'hasPerk': False},
#    {'id': '5b8c24546dcf04002c9c673c',
#     'name': 'Oslo Coffee Roasters',
#     'location': {'address': '236 W 10th St',
#      'lat': 40.733862641620995,
#      'lng': -74.0055236533668,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.733862641620995,
#        'lng': -74.0055236533668},
#       {'label': 'entrance', 'lat': 40.733807, 'lng': -74.005472}],
#      'distance': 572,
#      'postalCode': '10014',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['236 W 10th St',
#       'New York, NY 10014',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603720681',
#     'hasPerk': False},
#    {'id': '59a56b5e15173e2a7a007e9e',
#     'name': 'Gregorys Coffee',
#     'location': {'address': '525 Washington Blvd',
#      'lat': 40.72693,
#      'lng': -74.03559,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.72693,
#        'lng': -74.03559}],
#      'distance': 2185,
#      'postalCode': '07310',
#      'cc': 'US',
#      'neighborhood': 'Newport',
#      'city': 'Jersey City',
#      'state': 'NJ',
#      'country': 'United States',
#      'formattedAddress': ['525 Washington Blvd',
#       'Jersey City, NJ 07310',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1043356',
#      'url': 'https://www.grubhub.com/restaurant/gregorys-coffee-525-washington-blvd-jersey-city/1043356?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1043356',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'venuePage': {'id': '449080961'},
#     'referralId': 'v-1603720681',
#     'hasPerk': False}]}}
